# %% [markdown]
# <a href="https://colab.research.google.com/github/Aries2003/raiseLab/blob/main/RaiseLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !df -h
# Out:
# Filesystem                   Size  Used Avail Use% Mounted on
# tmpfs                        101G   61M  101G   1% /run
# efivarfs                     128K   44K   80K  36% /sys/firmware/efi/efivars
# /dev/nvme0n1p2               1.5T  506G  929G  36% /
# tmpfs                        504G  352M  504G   1% /dev/shm
# tmpfs                        5.0M     0  5.0M   0% /run/lock
# /dev/nvme0n1p1               1.1G  6.2M  1.1G   1% /boot/efi
# /dev/nvme0n1p4               1.9T  681G  1.2T  38% /var
# /dev/md127                   3.5T  2.1T  1.2T  65% /scratch
# 140.192.28.20:/srv/home      317T   17T  285T   6% /home
# 140.192.28.20:/srv/projects  327T   14T  297T   5% /projects
# tmpfs                        101G   16K  101G   1% /run/user/1084930734
# tmpfs                        101G  228K  101G   1% /run/user/1084838583
# tmpfs                        101G   48K  101G   1% /run/user/1084976252
# tmpfs                        101G   16K  101G   1% /run/user/1084929589
# ...

# %%
# !ls /home/valmeid1/
# Out:
# raiseLab  synGen

# %%
# !cd /home/valmeid1/raiseLab/dataset/ && ls
# Out:
# ARC-Challenge  ARC-Easy  README.md
